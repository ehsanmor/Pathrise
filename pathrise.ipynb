# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read an overview of the dataframe(Data understanding)

# %%
df=pd.read_excel('Data_Pathrise.xlsx')

# %%
df.head()
# Out:
#     id pathrise_status primary_track cohort_tag  program_duration_days  \
# 0  1.0          Active           SWE     OCT19A                    NaN
# 1  2.0          Active           PSO     JAN20A                    NaN
# 2  3.0     Closed Lost        Design     AUG19B                    0.0
# 3  4.0     Closed Lost           PSO     AUG19B                    0.0
# 4  5.0          Placed           SWE     AUG19A                   89.0
#
#    placed  employment_status  highest_level_of_education length_of_job_search  \
# 0     0.0          Unemployed          Bachelor's Degree           3-5 months
# 1     0.0          Unemployed    Some College, No Degree           3-5 months
# 2     0.0  Employed Part-Time            Master's Degree  Less than one month
# 3     0.0          Contractor          Bachelor's Degree  Less than one month
# 4     1.0          Unemployed          Bachelor's Degree           1-2 months
#
#             biggest_challenge_in_search professional_experience  \
# ...

# %%
df.tail()
# Out:
#           id     pathrise_status primary_track cohort_tag  \
# 2539  2540.0  Withdrawn (Failed)        Design     JUN18A
# 2540  2541.0  Withdrawn (Failed)          Data     JAN19B
# 2541  2542.0              Active           SWE     SEP18C
# 2542  2543.0              Active           SWE     MAY18A
# 2543  2544.0           Withdrawn           SWE     OCT19A
#
#       program_duration_days  placed employment_status   \
# 2539                  457.0     0.0         Contractor
# 2540                  488.0     0.0                NaN
# 2541                    NaN     0.0         Contractor
# 2542                    NaN     0.0                NaN
# 2543                  285.0     0.0            Student
#
#      highest_level_of_education length_of_job_search  \
# 2539            Master's Degree   6 months to a year
# 2540            Master's Degree           3-5 months
# 2541          Bachelor's Degree  Less than one month
# 2542            Master's Degree  Less than one month
# ...

# %%
df.shape
# Out:
# (2544, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2544 entries, 0 to 2543
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           2544 non-null   float64
#  1   pathrise_status              2544 non-null   object
#  2   primary_track                2544 non-null   object
#  3   cohort_tag                   2536 non-null   object
#  4   program_duration_days        1928 non-null   float64
#  5   placed                       2544 non-null   float64
#  6   employment_status            2315 non-null   object
#  7   highest_level_of_education   2486 non-null   object
#  8   length_of_job_search         2470 non-null   object
#  9   biggest_challenge_in_search  2520 non-null   object
#  10  professional_experience      2322 non-null   object
#  11  work_authorization_status    2260 non-null   object
#  12  number_of_interviews         2326 non-null   float64
# ...

# %%
df.dtypes
# Out:
# id                             float64
# pathrise_status                 object
# primary_track                   object
# cohort_tag                      object
# program_duration_days          float64
# placed                         float64
# employment_status               object
# highest_level_of_education      object
# length_of_job_search            object
# biggest_challenge_in_search     object
# professional_experience         object
# work_authorization_status       object
# number_of_interviews           float64
# number_of_applications         float64
# gender                          object
# race                            object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'pathrise_status', 'primary_track', 'cohort_tag',
#        'program_duration_days', 'placed', 'employment_status ',
#        'highest_level_of_education', 'length_of_job_search',
#        'biggest_challenge_in_search', 'professional_experience',
#        'work_authorization_status', 'number_of_interviews',
#        'number_of_applications', 'gender', 'race'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 id  program_duration_days       placed  number_of_interviews  \
# count  2544.000000            1928.000000  2544.000000           2326.000000
# mean   1272.500000             136.098548     0.375786              2.182287
# std     734.533866             125.860248     0.484420              2.959273
# min       1.000000               0.000000     0.000000              0.000000
# 25%     636.750000              14.000000     0.000000              0.000000
# 50%    1272.500000             112.000000     0.000000              1.000000
# 75%    1908.250000             224.000000     1.000000              3.000000
# max    2544.000000             548.000000     1.000000             20.000000
#
#        number_of_applications
# count             2544.000000
# mean                36.500786
# std                 53.654896
# min                  0.000000
# 25%                  9.000000
# 50%                 20.000000
# 75%                 45.000000
# ...

# %% [markdown]
# ### Rectification of Column Names.

# %%
#To eliminate the whitespace contained within the quotation marks.
df.columns = df.columns.str.strip()

# %%
# Set the figure size and font scale
sns.set(rc={'figure.figsize':(15, 10)}, font_scale=1.5)

# Create the categorical plot
cat_plot = sns.catplot(
    x='number_of_interviews', 
    y='program_duration_days', 
    hue='placed', 
    data=df, 
    aspect=3
)

# Set the axis labels
cat_plot.set_axis_labels("Number of Interviews", "Program Duration (Days)")

# Set the legend title and font size
cat_plot._legend.set_title("Placed")
for text in cat_plot._legend.texts:
    text.set_fontsize(20)

# Set the title for the plot
plt.title("Program Duration vs. Number of Interviews by Placement Status", fontsize=25)

# Display the plot
plt.show()

# %%
sns.countplot(data=df, x='pathrise_status', hue='placed', palette='muted')
plt.xticks(rotation=45)
plt.show()

# %%
df['pathrise_status'].unique()
# Out:
# array(['Active', 'Closed Lost', 'Placed', 'Withdrawn (Failed)',
#        'Withdrawn (Trial)', 'Withdrawn', 'Deferred', 'Break', 'MIA'],
#       dtype=object)

# %%
df['pathrise_status'].value_counts()
# Out:
# Placed                956
# Active                532
# Withdrawn             398
# Withdrawn (Trial)     276
# Closed Lost           182
# Withdrawn (Failed)     82
# MIA                    52
# Deferred               34
# Break                  32
# Name: pathrise_status, dtype: int64

# %%
sns.countplot(x='primary_track', data=df)
plt.xticks(rotation=90)
plt.ylabel('Count')
plt.show()

# %%
df["primary_track"].value_counts()
# Out:
# SWE          1678
# PSO           322
# Design        288
# Data          248
# Web             6
# Marketing       2
# Name: primary_track, dtype: int64

# %%
df["primary_track"].describe()
# Out:
# count     2544
# unique       6
# top        SWE
# freq      1678
# Name: primary_track, dtype: object

# %%
# sns.countplot(x= 'cohort_tag', data=df)
# plt.show()

plt.figure(figsize=(15, 8))
sns.countplot(x='cohort_tag', data=df)
plt.xticks(rotation=100)
plt.xlabel('Cohort Tag')
plt.ylabel('Count')
plt.show()

# %%
df["cohort_tag"].value_counts()
# Out:
# JAN19A    132
# JAN20A    124
# DEC18A    116
# FEB20A    108
# AUG19C     88
# OCT18B     84
# OCT18A     82
# AUG19B     82
# JAN20B     82
# JAN19B     74
# MAR19A     74
# OCT19A     68
# SEP19B     66
# JUL19A     66
# JUN19B     64
# DEC19A     64
# FEB19A     64
# NOV18A     62
# NOV19A     62
# SEP19A     60
# AUG19A     60
# OCT19B     54
# SEP18C     54
# JUN19A     54
# SEP18B     50
# AUG18A     50
# SEP18A     48
# APR19A     48
# JUN18A     48
# JUL19B     44
# MAR19B     44
# FEB19B     42
# NOV19B     40
# APR19B     34
# MAY18A     32
# MAR18A     30
# APR18B     30
# FEB18A     30
# FEB20B     28
# APR18A     24
# MAY19B     20
# MAY19A     18
# MAR20A     10
# JAN18A     10
# APR20A      6
# FEB20a      4
# OCT21A      2
# Name: cohort_tag, dtype: int64

# %%
df['cohort_tag'].unique()
# Out:
# array(['OCT19A', 'JAN20A', 'AUG19B', 'AUG19A', 'SEP19A', 'AUG19C',
#        'DEC19A', 'FEB20A', 'NOV19A', 'NOV19B', 'JAN20B', 'FEB20B',
#        'JUL19B', 'APR20A', 'OCT18A', 'SEP18C', 'OCT18B', 'JAN19A',
#        'MAR19A', 'FEB19A', 'FEB19B', 'APR19A', 'AUG18A', 'DEC18A',
#        'MAR19B', 'JAN19B', 'JUN19B', 'SEP18B', 'NOV18A', 'SEP18A',
#        'APR19B', 'MAY19A', 'JUL19A', 'JUN19A', 'FEB18A', 'JUN18A',
#        'MAR18A', 'APR18A', 'APR18B', 'MAY18A', 'OCT21A', 'SEP19B',
#        'MAR20A', 'MAY19B', 'FEB20a', 'OCT19B', 'JAN18A', nan],
#       dtype=object)

# %%
plt.figure(figsize=(10, 4))
sns.countplot(x='employment_status', data=df)
plt.xticks(rotation=100)
plt.xlabel('Cohort Tag')
plt.ylabel('Count')
plt.show()

# %%
# df_s= df.isnull().sum().sort_values(ascending=False)
# df_s

# %%
df["program_duration_days"].value_counts()

# %%
len(set(df["program_duration_days"]))

# %%
df["program_duration_days"].describe()

# %%
df["work_authorization_status"].value_counts()

# %%
df["employment_status "].value_counts()

# %%
df["employment_status "].describe()

# %%
df["professional_experience"].value_counts()

# %%
df["number_of_interviews"].value_counts()

# %%
df["length_of_job_search"].value_counts()

# %%
df["highest_level_of_education"].value_counts()

# %%
df["biggest_challenge_in_search"].value_counts()

# %%
df["race"].value_counts()

# %%
df["placed"].value_counts()

# %%
df["placed"].describe()

# %% [markdown]
#  ## drop the columns that do not affect the result

# %%
df= df.drop(['id', 'pathrise_status', 'cohort_tag'], axis=1)

# %%
df.info()

# %%
df_success= df[df['placed']==1]

# %%
df_success.info()

# %%
df_unsuccess= df[df['placed']!=1]

# %%
df_unsuccess.info()

# %%
df.isnull().values.any()

# %%
# Set the figure size and font scale
sns.set(rc={'figure.figsize':(15, 10)}, font_scale=1.5)

# Create the categorical plot
cat_plot = sns.catplot(
    x='number_of_interviews', 
    y='program_duration_days', 
    hue='placed', 
    data=df, 
    aspect=3
)

# Set the axis labels
cat_plot.set_axis_labels("Number of Interviews", "Program Duration (Days)")

# Set the legend title and font size
cat_plot._legend.set_title("Placed")
for text in cat_plot._legend.texts:
    text.set_fontsize(20)

# Set the title for the plot
plt.title("Program Duration vs. Number of Interviews by Placement Status", fontsize=25)

# Display the plot
plt.show()
